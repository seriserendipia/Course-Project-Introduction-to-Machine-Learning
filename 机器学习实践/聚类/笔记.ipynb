# %%
#自动重载外部文件的更新
# %load_ext autoreload
# %autoreload 2

# 添加项目路径至path
import os
import sys
currentPath = os.path.join(os.getcwd(),"machinelearningIntro","机器学习实践/聚类")
sys.path.append(currentPath)

# %% [markdown]
# 分类型数据要独热编码
#
# 连续型数据标准化
#
#
# #### 样本点常用距离
# 连续值：闵可夫斯基距离 Lp距离
# 某点到零点的距离称为该距离的Lp范数
#
# 分类值：取值相同的属性的数量，汉明距离
#
# 余弦相似度
#
# k值的选取：肘部图
#
# k均值容易受到极值或孤立点影响 => k中心

# %% [markdown]
# # kmode算法
# 离散分类值
#
# 汉明距离 = 两个相同长度的字符串在相同位置上不同字符的个数
# 两个样本间取值不同的属性的数量
#
# 质心 = 本类内一个属性的众数（众数多于一个时随机选一个）

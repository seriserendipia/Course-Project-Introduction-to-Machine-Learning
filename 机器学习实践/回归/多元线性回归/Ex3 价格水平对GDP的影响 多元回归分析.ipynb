# %%
#自动重载外部文件的更新
# %load_ext autoreload
# %autoreload 2

# 添加项目路径至path
import os
import sys
currentPath = os.path.join(os.getcwd(),"machinelearningIntro","机器学习实践/回归/多元线性回归")
sys.path.append(currentPath)

# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
# 导入数据
datadir = r"D:\PythonEx\machinelearningIntro\data\Penn World Table.xlsx"
df = pd.read_excel(datadir)
df
# Out:
#     countrycode   country    currency_unit  year         rgdpe      pl_c  \
# 0           AGO    Angola           Kwanza  2007  58131.746094  1.253990
# 1           AGO    Angola           Kwanza  2008  67472.859375  1.418632
# 2           AGO    Angola           Kwanza  2009  59256.636719  1.681747
# 3           AGO    Angola           Kwanza  2010  76151.132812  1.195477
# 4           AGO    Angola           Kwanza  2011  82680.945312  1.294905
# ..          ...       ...              ...   ...           ...       ...
# 830         ZWE  Zimbabwe  Zimbabwe Dollar  2007  45666.082031  0.155326
# 831         ZWE  Zimbabwe  Zimbabwe Dollar  2008  35789.878906  0.187243
# 832         ZWE  Zimbabwe  Zimbabwe Dollar  2009  49294.878906  0.112196
# 833         ZWE  Zimbabwe  Zimbabwe Dollar  2010  51259.152344  0.123692
# 834         ZWE  Zimbabwe  Zimbabwe Dollar  2011  55453.312500  0.140521
#
#          pl_i      pl_g      pl_x      pl_m      pl_k
# 0    0.738191  1.076301  0.650072  0.764166  0.617699
# 1    0.938361  1.352946  0.774891  0.937404  0.777646
# 2    0.786687  1.105007  0.829843  1.190549  0.657191
# 3    0.843884  1.161518  0.920334  0.961341  0.706732
# 4    1.048095  1.460608  1.194767  1.239069  0.868282
# ..        ...       ...       ...       ...       ...
# 830  0.096808  0.030871  0.836226  0.704391  1.322423
# 831  0.075830  0.017838  0.812021  0.899782  0.920607
# 832  0.211507  0.153393  0.274833  0.375842  3.617210
# 833  0.237427  0.168766  0.298547  0.407374  4.071371
# 834  0.254450  0.182873  0.296839  0.434173  9.279111
#
# [835 rows x 11 columns]

# %%
df.columns
# Out:
# Index(['countrycode', 'country', 'currency_unit', 'year', 'rgdpe', 'pl_c',
#        'pl_i', 'pl_g', 'pl_x', 'pl_m', 'pl_k'],
#       dtype='object')

# %%
df.year.value_counts()
# Out:
# 2007    167
# 2008    167
# 2009    167
# 2010    167
# 2011    167
# Name: year, dtype: int64

# %%
data = df[['pl_c','pl_i', 'pl_g', 'pl_x', 'pl_m', 'pl_k','rgdpe']]
data = np.log(data)
x_data = df[['pl_c','pl_i', 'pl_g', 'pl_x', 'pl_m', 'pl_k']]
y_data = df[['rgdpe']]

# %%
# 探索性分析
data.describe()
# Out:
#              pl_c        pl_i        pl_g        pl_x        pl_m        pl_k  \
# count  835.000000  835.000000  835.000000  835.000000  835.000000  835.000000
# mean    -0.290392   -0.187144   -0.453663   -0.135787   -0.204165   -0.346885
# std      0.416546    0.486217    0.716834    0.160531    0.137122    0.580939
# min     -2.187510   -2.579259   -4.026440   -1.291590   -0.978587   -1.779965
# 25%     -0.545993   -0.475354   -0.900372   -0.207646   -0.290009   -0.732292
# 50%     -0.335342   -0.239924   -0.427703   -0.132980   -0.201642   -0.425493
# 75%     -0.012210    0.066378    0.112809   -0.056968   -0.126762   -0.038758
# max      1.296542    1.812715    1.002211    0.450231    0.379142    2.227766
#
#             rgdpe
# count  835.000000
# mean    10.833934
# std      2.125492
# min      5.487704
# 25%      9.389024
# 50%     10.747978
# 75%     12.429206
# max     16.411739

# %%
# heatmap看共线性
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
data.corr()
# Out:
#            pl_c      pl_i      pl_g      pl_x      pl_m      pl_k     rgdpe
# pl_c   1.000000  0.638262  0.656078  0.174334  0.297147  0.547620  0.095560
# pl_i   0.638262  1.000000  0.371734  0.161057  0.238059  0.852176 -0.126312
# pl_g   0.656078  0.371734  1.000000  0.160477  0.268314  0.325628  0.296902
# pl_x   0.174334  0.161057  0.160477  1.000000  0.501256 -0.006860 -0.009540
# pl_m   0.297147  0.238059  0.268314  0.501256  1.000000  0.095693  0.294240
# pl_k   0.547620  0.852176  0.325628 -0.006860  0.095693  1.000000 -0.111779
# rgdpe  0.095560 -0.126312  0.296902 -0.009540  0.294240 -0.111779  1.000000

# %%
data_lg = data[['pl_i', 'pl_g', 'pl_x', 'pl_m', 'rgdpe']]
data_lg.corr()
# Out:
#            pl_i      pl_g      pl_x      pl_m     rgdpe
# pl_i   1.000000  0.371734  0.161057  0.238059 -0.126312
# pl_g   0.371734  1.000000  0.160477  0.268314  0.296902
# pl_x   0.161057  0.160477  1.000000  0.501256 -0.009540
# pl_m   0.238059  0.268314  0.501256  1.000000  0.294240
# rgdpe -0.126312  0.296902 -0.009540  0.294240  1.000000

# %%
sns.boxplot(data)
# Out:
# <AxesSubplot:>

# %%
#TODO  删去上下四分位之外的极值

# %%
from lineartrain_from_老师 import linear_train
import matplotlib.pyplot as plt

# %%
#拆分训练集和测试集
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(x_data,y_data,test_size = 0.9,random_state=123456)

# %%
loss_his, params, grads = linear_train(X_train,y_train,0.01,100)
print(params['w'])
print(min(loss_his))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [15], line 1
# ----> 1 loss_his, params, grads = linear_train(X_train,y_train,0.01,100)
#       2 print(params['w'])
#       3 print(min(loss_his))
#
# File D:\PythonEx\machinelearningIntro\机器学习实践/回归/多元线性回归\lineartrain_from_老师.py:47, in linear_train(x, y, learning_rate, epochs)
#      43 w, b = init_param(x.shape[1])
#      45 for i in range(1, epochs):
#      46     #     计算当前迭代的预测值，均方损失和梯度
# ---> 47     y_hat, loss, dw, db = linear_loss(x, y, w, b)
#      48     w += learning_rate * dw
#      49     b += learning_rate * db
#
# File D:\PythonEx\machinelearningIntro\机器学习实践/回归/多元线性回归\lineartrain_from_老师.py:34, in linear_loss(x, y, w, b)
#      32 num_train = x.shape[0]
#      33 num_feature = x.shape[1]  # TODO num_feature 没有用
# ---> 34 y_hat = np.dot(x, w) + b
#      35 loss = np.sum((y_hat - y) ** 2) / num_train  # 均方损失
#      36 dw = np.dot(x.T, (y_hat - y)) / num_train  # TODO 基于均方差损失对权重系数的一阶梯度
#
# File <__array_function__ internals>:5, in dot(*args, **kwargs)
#
# ValueError: shapes (83,6) and (1,7) not aligned: 6 (dim 1) != 1 (dim 0)

# %%
plt.figure(figsize=(8,6))
plt.plot(loss_his)
plt.xlabel('迭代次数')
plt.ylabel('最小损失值')
plt.title('最小损失值变化')
plt.show()

# %%
sns.histplot(X_train).set(xscale = 'log')

# %%
X_train
